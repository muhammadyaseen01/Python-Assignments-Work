# %%
import pandas as pd

# %%
data = pd.read_csv("covid_19_country_wise_latest.csv")
data
# Out:
#      Unnamed: 0      Country/Region  Confirmed Deaths  Recovered  Active  \
# 0             0         Afghanistan      36263   1269      25198    9796
# 1             1             Albania       4880    144       2745    1991
# 2             2             Algeria      27973   1163      18837    7973
# 3             3             Andorra        907     52        803      52
# 4             4              Angola        950     41        242     667
# ..          ...                 ...        ...    ...        ...     ...
# 182         182  West Bank and Gaza      10621     78       3752    6791
# 183         183      Western Sahara         10      1          8       1
# 184         184               Yemen       1691    483        833     375
# 185         185              Zambia       4552    140       2815    1597
# 186         186            Zimbabwe       2704    non        542    2126
#
#      New cases  New deaths  New recovered  Deaths / 100 Cases  \
# ...

# %%
data.head()
# Out:
#    Unnamed: 0 Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# 0           0    Afghanistan      36263   1269      25198    9796      106.0
# 1           1        Albania       4880    144       2745    1991      117.0
# 2           2        Algeria      27973   1163      18837    7973      616.0
# 3           3        Andorra        907     52        803      52       10.0
# 4           4         Angola        950     41        242     667       18.0
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0        10.0             18                3.50                  69.49
# 1         6.0             63                2.95                  56.25
# 2         8.0            749                4.16                  67.34
# 3         0.0              0                5.73                  88.53
# 4         1.0              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
data = pd.read_csv("covid_19_country_wise_latest.csv",index_col="Unnamed: 0")
data
# Out:
#          Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263   1269      25198    9796      106.0
# 1               Albania       4880    144       2745    1991      117.0
# 2               Algeria      27973   1163      18837    7973      616.0
# 3               Andorra        907     52        803      52       10.0
# 4                Angola        950     41        242     667       18.0
# ..                  ...        ...    ...        ...     ...        ...
# 182  West Bank and Gaza      10621     78       3752    6791      152.0
# 183      Western Sahara         10      1          8       1        0.0
# 184               Yemen       1691    483        833     375       10.0
# 185              Zambia       4552    140       2815    1597       71.0
# 186            Zimbabwe       2704    non        542    2126      192.0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.rename(columns={"Unnamed: 0":'Index',"Country/Region":"Country"},inplace=True)

# %%
def replace_whitespaces(data):
    data.columns = data.columns.str.replace(" ", "_", regex=True)
    return data

data = replace_whitespaces(data)
print("After the white spaces:")
print(data.columns)
# Out:
# After the white spaces:
# Index(['Country', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New_cases',
#        'New_deaths', 'New_recovered', 'Deaths_/_100_Cases',
#        'Recovered_/_100_Cases', 'Deaths_/_100_Recovered',
#        'Confirmed_last_week', '1_week_change', '1_week_%_increase',
#        'WHO_Region'],
#       dtype='object')

# %%
data
# Out:
#                 Country  Confirmed Deaths  Recovered  Active  New_cases  \
# 0           Afghanistan      36263   1269      25198    9796      106.0
# 1               Albania       4880    144       2745    1991      117.0
# 2               Algeria      27973   1163      18837    7973      616.0
# 3               Andorra        907     52        803      52       10.0
# 4                Angola        950     41        242     667       18.0
# ..                  ...        ...    ...        ...     ...        ...
# 182  West Bank and Gaza      10621     78       3752    6791      152.0
# 183      Western Sahara         10      1          8       1        0.0
# 184               Yemen       1691    483        833     375       10.0
# 185              Zambia       4552    140       2815    1597       71.0
# 186            Zimbabwe       2704    non        542    2126      192.0
#
#      New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    object
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New_cases               177 non-null    float64
#  6   New_deaths              177 non-null    float64
#  7   New_recovered           187 non-null    int64
#  8   Deaths_/_100_Cases      187 non-null    float64
#  9   Recovered_/_100_Cases   187 non-null    float64
#  10  Deaths_/_100_Recovered  187 non-null    float64
#  11  Confirmed_last_week     187 non-null    int64
#  12  1_week_change           187 non-null    int64
#  13  1_week_%_increase       187 non-null    float64
# ...

# %%
data.isna().sum()
# Out:
# Country                    0
# Confirmed                  0
# Deaths                     0
# Recovered                  0
# Active                     0
# New_cases                 10
# New_deaths                10
# New_recovered              0
# Deaths_/_100_Cases         0
# Recovered_/_100_Cases      0
# Deaths_/_100_Recovered     0
# Confirmed_last_week        0
# 1_week_change              0
# 1_week_%_increase          0
# WHO_Region                 0
# dtype: int64

# %%
data.New_cases.mean()
# Out:
# 1282.7401129943503

# %%
data.New_deaths.mean()
# Out:
# 30.401129943502823

# %%
data.fillna({"New_cases":data.New_cases.mean(),
             "New_deaths":data.New_deaths.mean()},inplace=True)

# %%
data.isna().sum()
# Out:
# Country                   0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New_cases                 0
# New_deaths                0
# New_recovered             0
# Deaths_/_100_Cases        0
# Recovered_/_100_Cases     0
# Deaths_/_100_Recovered    0
# Confirmed_last_week       0
# 1_week_change             0
# 1_week_%_increase         0
# WHO_Region                0
# dtype: int64

# %%
#data["Country/Region"].unique()
data.Country.value_counts()
# Out:
# Country
# Afghanistan    1
# Pakistan       1
# Nepal          1
# Netherlands    1
# New Zealand    1
#               ..
# Georgia        1
# Germany        1
# Ghana          1
# Greece         1
# Zimbabwe       1
# Name: count, Length: 187, dtype: int64

# %%
data.duplicated(subset=['Country']).sum()
# Out:
# 0

# %%
data.describe()
# Out:
#           Confirmed     Recovered        Active     New_cases   New_deaths  \
# count  1.870000e+02  1.870000e+02  1.870000e+02    187.000000   187.000000
# mean   8.813094e+04  5.063148e+04  3.400194e+04   1282.740113    30.401130
# std    3.833187e+05  1.901882e+05  2.133262e+05   5704.395582   119.874498
# min    1.000000e+01  0.000000e+00  0.000000e+00      0.000000     0.000000
# 25%    1.114000e+03  6.265000e+02  1.415000e+02      5.000000     0.000000
# 50%    5.059000e+03  2.815000e+03  1.600000e+03     71.000000     1.000000
# 75%    4.046050e+04  2.260600e+04  9.149000e+03    586.500000     7.500000
# max    4.290259e+06  1.846641e+06  2.816444e+06  56336.000000  1076.000000
#
#        New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# count     187.000000          187.000000             187.000000
# mean      933.812834            3.019519              64.820535
# std      4197.719635            3.454302              26.287694
# ...

# %%
data.Deaths.value_counts()
# Out:
# Deaths
# 0       17
# 11       4
# 1        3
# 10       3
# 2        3
#         ..
# 408      1
# 4652     1
# 5532     1
# 1083     1
# non      1
# Name: count, Length: 150, dtype: int64

# %%
data.fillna({"Deaths":data.Deaths[0]},inplace=True)

# %%
data.Deaths = data.Deaths.str.replace("non","19666").astype(int)

# %%
data.Deaths = data.Deaths.replace(19666,data.Deaths.mean())

# %%
data.Deaths.value_counts()
# Out:
# Deaths
# 0.000000       17
# 11.000000       4
# 1.000000        3
# 10.000000       3
# 2.000000        3
#                ..
# 408.000000      1
# 4652.000000     1
# 5532.000000     1
# 1083.000000     1
# 3602.491979     1
# Name: count, Length: 150, dtype: int64

# %%
data.Deaths.sum(),data.Recovered.sum()
# Out:
# (657602.4919786097, 9468087)

# %%
data[(data.Confirmed > 1000000)]
# Out:
#     Country  Confirmed    Deaths  Recovered   Active  New_cases  New_deaths  \
# 23   Brazil    2442375   87618.0    1846641   508116    23284.0       614.0
# 79    India    1480073   33408.0     951166   495499    44457.0       637.0
# 173      US    4290259  148011.0    1325804  2816444    56336.0      1076.0
#
#      New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# 23           33728                3.59                  75.61
# 79           33598                2.26                  64.26
# 173          27941                3.45                  30.90
#
#      Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# 23                     4.74              2118646         323729
# 79                     3.51              1155338         324735
# 173                   11.16              3834677         455582
#
#      1_week_%_increase       WHO_Region
# 23               15.28         Americas
# 79               28.11  South-East Asia
# ...

# %%
data[((data.Recovered / data.Confirmed)== 0.95)]
# Out:
#    Country  Confirmed  Deaths  Recovered  Active  New_cases  New_deaths  \
# 94    Laos         20     0.0         19       1        0.0         0.0
#
#     New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# 94              0                 0.0                   95.0
#
#     Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# 94                     0.0                   19              1
#
#     1_week_%_increase       WHO_Region
# 94               5.26  Western Pacific

# %%
data.drop('WHO_Region', axis=1, inplace=True)
data.drop('Confirmed', axis=1, inplace=True)

# %%
data
# Out:
#                 Country       Deaths  Recovered  Active  New_cases  \
# 0           Afghanistan  1269.000000      25198    9796      106.0
# 1               Albania   144.000000       2745    1991      117.0
# 2               Algeria  1163.000000      18837    7973      616.0
# 3               Andorra    52.000000        803      52       10.0
# 4                Angola    41.000000        242     667       18.0
# ..                  ...          ...        ...     ...        ...
# 182  West Bank and Gaza    78.000000       3752    6791      152.0
# 183      Western Sahara     1.000000          8       1        0.0
# 184               Yemen   483.000000        833     375       10.0
# 185              Zambia   140.000000       2815    1597       71.0
# 186            Zimbabwe  3602.491979        542    2126      192.0
#
#      New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# 0          10.0             18                3.50                  69.49
# ...

# %%
data.Deaths.max()
data[data.Deaths==data.Deaths.max()]
# Out:
#     Country    Deaths  Recovered   Active  New_cases  New_deaths  \
# 173      US  148011.0    1325804  2816444    56336.0      1076.0
#
#      New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# 173          27941                3.45                   30.9
#
#      Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# 173                   11.16              3834677         455582
#
#      1_week_%_increase
# 173              11.88

# %%
data.sort_values(by='Deaths', ascending=False)
# Out:
#               Country    Deaths  Recovered   Active     New_cases  New_deaths  \
# 173                US  148011.0    1325804  2816444  56336.000000  1076.00000
# 23             Brazil   87618.0    1846641   508116  23284.000000   614.00000
# 177    United Kingdom   45844.0       1437   254427    688.000000     7.00000
# 111            Mexico   44022.0     303810    47657   4973.000000   342.00000
# 85              Italy   35112.0     198593    12581    168.000000     5.00000
# ..                ...       ...        ...      ...           ...         ...
# 19             Bhutan       0.0         86       13   1282.740113    30.40113
# 130  Papua New Guinea       0.0         11       51      0.000000     0.00000
# 75           Holy See       0.0         12        0      0.000000     0.00000
# 30           Cambodia       0.0        147       79      1.000000     0.00000
# 114          Mongolia       0.0        222       67      1.000000     0.00000
#
# ...

# %%
data['Total_cases'] = data['Deaths'] + data['Recovered'] + data['Active']
data
# Out:
#                 Country       Deaths  Recovered  Active  New_cases  \
# 0           Afghanistan  1269.000000      25198    9796      106.0
# 1               Albania   144.000000       2745    1991      117.0
# 2               Algeria  1163.000000      18837    7973      616.0
# 3               Andorra    52.000000        803      52       10.0
# 4                Angola    41.000000        242     667       18.0
# ..                  ...          ...        ...     ...        ...
# 182  West Bank and Gaza    78.000000       3752    6791      152.0
# 183      Western Sahara     1.000000          8       1        0.0
# 184               Yemen   483.000000        833     375       10.0
# 185              Zambia   140.000000       2815    1597       71.0
# 186            Zimbabwe  3602.491979        542    2126      192.0
#
#      New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# 0          10.0             18                3.50                  69.49
# ...

# %%
data['Death_Rate'] = (data['Deaths'] / data['Total_cases']) * 100
data
# Out:
#                 Country       Deaths  Recovered  Active  New_cases  \
# 0           Afghanistan  1269.000000      25198    9796      106.0
# 1               Albania   144.000000       2745    1991      117.0
# 2               Algeria  1163.000000      18837    7973      616.0
# 3               Andorra    52.000000        803      52       10.0
# 4                Angola    41.000000        242     667       18.0
# ..                  ...          ...        ...     ...        ...
# 182  West Bank and Gaza    78.000000       3752    6791      152.0
# 183      Western Sahara     1.000000          8       1        0.0
# 184               Yemen   483.000000        833     375       10.0
# 185              Zambia   140.000000       2815    1597       71.0
# 186            Zimbabwe  3602.491979        542    2126      192.0
#
#      New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# 0          10.0             18                3.50                  69.49
# ...

# %%
data.Total_cases.mean()
data.Death_Rate.mean()


data[(data.Total_cases > data.Total_cases.mean()) & (data.Death_Rate < data.Death_Rate.mean())]
# Out:
#           Country   Deaths  Recovered  Active     New_cases  New_deaths  \
# 6       Argentina   3059.0      72575   91782   4890.000000   120.00000
# 13     Bangladesh   2965.0     125683   97577   2772.000000    37.00000
# 35          Chile   9187.0     319954   18782   2133.000000    75.00000
# 79          India  33408.0     951166  495499  44457.000000   637.00000
# 128      Pakistan   5842.0     241026   27421   1176.000000    20.00000
# 136         Qatar    165.0     106328    3104    292.000000     0.00000
# 138        Russia  13334.0     602249  201097   5607.000000    85.00000
# 145  Saudi Arabia   2760.0     222936   43238   1993.000000    27.00000
# 154  South Africa   7067.0     274925  170537   7096.000000   298.00000
# 172        Turkey   5630.0     210469   10920   1282.740113    30.40113
#
#      New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# 6             2057                1.83                  43.35
# ...

# %%
data[['Country', 'Death_Rate']].head()
# Out:
#        Country  Death_Rate
# 0  Afghanistan    3.499435
# 1      Albania    2.950820
# 2      Algeria    4.157581
# 3      Andorra    5.733186
# 4       Angola    4.315789

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20,15))           #in inches
sns.scatterplot(data=data, x='Total_cases', y='Deaths', hue='Country')
# Out:
# <Axes: xlabel='Total_cases', ylabel='Deaths'>

# %%
data.to_csv("Covid-19-Data-Cleaned.csv")
